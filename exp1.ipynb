# %% [markdown]
# <a href="https://colab.research.google.com/github/kartheek1717/DataScience1/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas
import pandas as pd

# %%
# storing url of online csv file
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# %%
# reading csv file
df=pd.read_csv(url)

# %%
# Getting data from url csv file

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Storing all rows in csv file which named studentCSV.csv
df.to_csv("iris_output.csv",index=False)
print("Dataset of all rows successfully written to iris_output.csv")
# Out:
# Dataset of all rows successfully written to iris_output.csv

# %%
# storing first five rows in csv file which named student5csv.csv
temp=df.head()
temp.to_csv("student5csv.csv",index=False)
print("Dataset of 5 rows successfully written to student5csv.csv")
# Out:
# Dataset of 5 rows successfully written to student5csv.csv

# %%
# get Data from local files
url2="student5csvLocal.csv"
df2=pd.read_csv(url2)
print(df2.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_520/1434334370.py in <cell line: 0>()
#       1 # get Data from local files
#       2 url2="student5csvLocal.csv"
# ----> 3 df2=pd.read_csv(url2)
#       4 print(df2.head())
#
# ...
