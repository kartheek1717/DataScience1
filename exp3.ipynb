# %% [markdown]
# <a href="https://colab.research.google.com/github/kartheek1717/DataScience1/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("students.txt", "w") as f:
    f.write("RollNo\tName\tMarks\n")
    f.write("101\tRavi\t85\n")
    f.write("102\tPriya\t90\n")
    f.write("103\tKiran\t88\n")

# %%
import pandas as pd

df = pd.read_csv("students.txt", sep="\t")
print(df)
# Out:
#    RollNo   Name  Marks
# 0     101   Ravi     85
# 1     102  Priya     90
# 2     103  Kiran     88
