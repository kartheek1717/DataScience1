# %% [markdown]
# <a href="https://colab.research.google.com/github/kartheek1717/DataScience1/blob/main/parsing%20data%20from%20a%20string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# JSON string
json_string = '{"Name":"Kartheek","Age":20,"Course":"B.Tech","Marks":95}'

# Parse JSON string into Python dictionary
data = json.loads(json_string)

# Display data
print("Student Details:")
print(data)

print("Name:", data["Name"])
print("Age:", data["Age"])
print("Course:", data["Course"])
print("Marks:", data["Marks"])
# Out:
# Student Details:
# {'Name': 'Kartheek', 'Age': 20, 'Course': 'B.Tech', 'Marks': 95}
# Name: Kartheek
# Age: 20
# Course: B.Tech
# Marks: 95
